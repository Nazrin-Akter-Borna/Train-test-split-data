# %% [markdown]
# ####            Train data set /LinearRegression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model

# %%
df = pd.read_csv('train.csv')

# %%
df.shape
# Out:
# (700, 2)

# %%
df
# Out:
#      length      width
# 0      24.0  21.549452
# 1      50.0  47.464463
# 2      15.0  17.218656
# 3      38.0  36.586398
# 4      87.0  87.288984
# ..      ...        ...
# 695    58.0  58.595006
# 696    93.0  94.625094
# 697    82.0  88.603770
# 698    66.0  63.648685
# 699    97.0  94.975266
#
# [700 rows x 2 columns]

# %%
df.describe()
# Out:
#             length       width
# count   700.000000  699.000000
# mean     54.985939   49.939869
# std     134.681703   29.109217
# min       0.000000   -3.839981
# 25%      25.000000   24.929968
# 50%      49.000000   48.973020
# 75%      75.000000   74.929911
# max    3530.157369  108.871618

# %%
df.shape
# Out:
# (700, 2)

# %%
df.head(5)
# Out:
#    length      width
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984

# %%
df.tail(5)
# Out:
#      length      width
# 695    58.0  58.595006
# 696    93.0  94.625094
# 697    82.0  88.603770
# 698    66.0  63.648685
# 699    97.0  94.975266

# %%
plt.scatter(df.length,df.width,color="green",marker='+')
plt.xlabel('length')
plt.ylabel('width')
plt.title('single linear regression')
# Out:
# Text(0.5, 1.0, 'single linear regression')

# %%
import math
median_length=math.floor(df.length.median())

# %%
median_length
# Out:
# 49

# %%
df.length.fillna(median_length)
# Out:
# 0      24.0
# 1      50.0
# 2      15.0
# 3      38.0
# 4      87.0
#        ...
# 695    58.0
# 696    93.0
# 697    82.0
# 698    66.0
# 699    97.0
# Name: length, Length: 700, dtype: float64

# %%
df.length=df.length.fillna(median_length)
df
# Out:
#      length      width
# 0      24.0  21.549452
# 1      50.0  47.464463
# 2      15.0  17.218656
# 3      38.0  36.586398
# 4      87.0  87.288984
# ..      ...        ...
# 695    58.0  58.595006
# 696    93.0  94.625094
# 697    82.0  88.603770
# 698    66.0  63.648685
# 699    97.0  94.975266
#
# [700 rows x 2 columns]

# %%
df2=df.dropna(thresh=2)
df2
# Out:
#      length      width
# 0      24.0  21.549452
# 1      50.0  47.464463
# 2      15.0  17.218656
# 3      38.0  36.586398
# 4      87.0  87.288984
# ..      ...        ...
# 695    58.0  58.595006
# 696    93.0  94.625094
# 697    82.0  88.603770
# 698    66.0  63.648685
# 699    97.0  94.975266
#
# [699 rows x 2 columns]

# %% [markdown]
# np.reshape(1,-1)#

# %%
x=df2['length']
y=df2['width']

# %%
x = np.array(x).reshape(-1,1)
y = np.array(y).reshape(-1,1)

# %%
y
# Out:
# array([[ 21.54945196],
#        [ 47.46446305],
#        [ 17.21865634],
#        [ 36.58639803],
#        [ 87.28898389],
#        [ 32.46387493],
#        [ 10.78089683],
#        [ 80.7633986 ],
#        [ 24.61215147],
#        [  6.96331907],
#        [ 11.23757338],
#        [ 13.53290206],
#        [ 24.60323899],
#        [ 39.40049976],
#        [ 48.43753838],
#        [ 61.69900319],
#        [ 26.92832418],
#        [ 70.4052055 ],
#        [ 29.34092408],
#        [ 25.30895192],
#        [ 69.02934339],
#        [ 84.99484703],
#        [ 57.04310305],
#        [ 50.5921991 ],
#        [ 83.02772202],
#        [ 57.05752706],
#        [ 47.95883341],
#        [ 24.34226432],
#        [ 94.68488281],
#        [ 48.03970696],
#        [  7.08132338],
#        [ 21.99239907],
#        [ 42.33151664],
#        [  0.32908944],
#        [ 61.92303698],
#        [ 91.17716423],
#        [ 39.45358014],
#        [  5.99606961],
#        [ 22.59015942],
#        [ 61.18044414],
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.40)

# %%
x_train
# Out:
# array([[ 35.],
#        [ 26.],
#        [  8.],
#        [ 34.],
#        [ 71.],
#        [ 26.],
#        [ 87.],
#        [ 48.],
#        [ 42.],
#        [ 67.],
#        [ 86.],
#        [ 99.],
#        [ 19.],
#        [ 60.],
#        [ 91.],
#        [ 83.],
#        [ 84.],
#        [ 33.],
#        [ 14.],
#        [  1.],
#        [ 19.],
#        [ 91.],
#        [ 65.],
#        [ 41.],
#        [ 42.],
#        [ 88.],
#        [ 53.],
#        [ 98.],
#        [  5.],
#        [ 21.],
#        [ 47.],
#        [ 29.],
#        [ 25.],
#        [ 43.],
#        [ 36.],
#        [ 45.],
#        [ 46.],
#        [ 13.],
#        [  5.],
#        [ 30.],
#        [ 34.],
#        [ 75.],
#        [ 86.],
#        [ 54.],
#        [ 51.],
#        [ 14.],
#        [ 68.],
#        [ 23.],
#        [ 99.],
#        [  5.],
#        [ 42.],
#        [ 50.],
#        [ 34.],
#        [ 93.],
#        [ 86.],
#        [ 41.],
#        [ 87.],
#        [100.],
# ...

# %%
x_test
# Out:
# array([[ 88.],
#        [  2.],
#        [ 42.],
#        [ 39.],
#        [ 47.],
#        [ 56.],
#        [ 50.],
#        [ 90.],
#        [ 13.],
#        [ 58.],
#        [ 93.],
#        [ 77.],
#        [ 21.],
#        [ 16.],
#        [ 79.],
#        [ 99.],
#        [ 89.],
#        [ 84.],
#        [ 16.],
#        [ 68.],
#        [  2.],
#        [ 53.],
#        [ 58.],
#        [ 15.],
#        [ 17.],
#        [  4.],
#        [ 61.],
#        [ 85.],
#        [ 74.],
#        [ 59.],
#        [  8.],
#        [ 21.],
#        [ 58.],
#        [ 98.],
#        [ 27.],
#        [  0.],
#        [ 94.],
#        [ 67.],
#        [ 50.],
#        [ 52.],
#        [ 73.],
#        [ 64.],
#        [ 37.],
#        [ 67.],
#        [ 55.],
#        [ 39.],
#        [ 56.],
#        [  0.],
#        [ 98.],
#        [  8.],
#        [ 62.],
#        [ 79.],
#        [ 75.],
#        [ 38.],
#        [ 62.],
#        [ 66.],
#        [ 84.],
#        [ 98.],
# ...

# %%
y_train
# Out:
# array([[ 36.78035027],
#        [ 26.40362524],
#        [  2.37917248],
#        [ 36.33294447],
#        [ 70.3188322 ],
#        [ 28.90055826],
#        [ 89.93374342],
#        [ 53.62523007],
#        [ 38.46213684],
#        [ 66.04325304],
#        [ 85.03295412],
#        [ 99.9566225 ],
#        [ 18.40919388],
#        [ 56.99178872],
#        [ 85.23492274],
#        [ 81.4281205 ],
#        [ 86.10796637],
#        [ 33.22031418],
#        [ 10.26712261],
#        [ -3.83998112],
#        [ 20.87391785],
#        [ 91.64730552],
#        [ 60.53321778],
#        [ 43.26595082],
#        [ 50.05636123],
#        [ 90.5799868 ],
#        [ 49.21863516],
#        [ 95.2389253 ],
#        [  1.61194747],
#        [ 18.44679787],
#        [ 44.15029394],
#        [ 29.34092408],
#        [ 21.37698317],
#        [ 41.02251779],
#        [ 32.77049249],
#        [ 43.9367213 ],
#        [ 47.88388961],
#        [ 14.81106804],
#        [  7.38224417],
#        [ 29.76846185],
# ...

# %%
y_test
# Out:
# array([[ 87.67388681],
#        [ -0.1218605 ],
#        [ 43.64765048],
#        [ 41.39990349],
#        [ 48.71787679],
#        [ 55.9249564 ],
#        [ 47.04654956],
#        [ 86.236707  ],
#        [ 13.11612884],
#        [ 61.94273962],
#        [ 94.55203143],
#        [ 74.12151511],
#        [ 22.5453232 ],
#        [ 16.01629889],
#        [ 76.92664854],
#        [100.0953697 ],
#        [ 84.48045678],
#        [ 83.1286166 ],
#        [ 17.9170699 ],
#        [ 69.02934339],
#        [  2.26705945],
#        [ 56.37058203],
#        [ 61.7510743 ],
#        [ 17.21865634],
#        [ 17.33681562],
#        [  9.68240849],
#        [ 66.16652565],
#        [ 82.69087513],
#        [ 72.6356699 ],
#        [ 61.69026202],
#        [ 10.240085  ],
#        [ 22.51016575],
#        [ 54.14681616],
#        [ 92.85929155],
#        [ 26.68273277],
#        [ -3.83665214],
#        [ 96.19000542],
#        [ 65.84975426],
#        [ 49.82634062],
#        [ 51.70352433],
# ...

# %% [markdown]
# from sklearn.linear_model import LinearRegression
# reg=LinearRegression()
# reg.fit(x_train,y_train)

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
x_test
# Out:
# array([[ 88.],
#        [  2.],
#        [ 42.],
#        [ 39.],
#        [ 47.],
#        [ 56.],
#        [ 50.],
#        [ 90.],
#        [ 13.],
#        [ 58.],
#        [ 93.],
#        [ 77.],
#        [ 21.],
#        [ 16.],
#        [ 79.],
#        [ 99.],
#        [ 89.],
#        [ 84.],
#        [ 16.],
#        [ 68.],
#        [  2.],
#        [ 53.],
#        [ 58.],
#        [ 15.],
#        [ 17.],
#        [  4.],
#        [ 61.],
#        [ 85.],
#        [ 74.],
#        [ 59.],
#        [  8.],
#        [ 21.],
#        [ 58.],
#        [ 98.],
#        [ 27.],
#        [  0.],
#        [ 94.],
#        [ 67.],
#        [ 50.],
#        [ 52.],
#        [ 73.],
#        [ 64.],
#        [ 37.],
#        [ 67.],
#        [ 55.],
#        [ 39.],
#        [ 56.],
#        [  0.],
#        [ 98.],
#        [  8.],
#        [ 62.],
#        [ 79.],
#        [ 75.],
#        [ 38.],
#        [ 62.],
#        [ 66.],
#        [ 84.],
#        [ 98.],
# ...

# %%
clf.predict(x_test)
# Out:
# array([[ 88.09098618],
#        [  1.55193433],
#        [ 41.80265612],
#        [ 38.78385199],
#        [ 46.83399635],
#        [ 55.89040875],
#        [ 49.85280048],
#        [ 90.10352227],
#        [ 12.62088283],
#        [ 57.90294484],
#        [ 93.12232641],
#        [ 77.02203769],
#        [ 20.67102718],
#        [ 15.63968696],
#        [ 79.03457378],
#        [ 99.15993468],
#        [ 89.09725423],
#        [ 84.06591401],
#        [ 15.63968696],
#        [ 67.96562529],
#        [  1.55193433],
#        [ 52.87160462],
#        [ 57.90294484],
#        [ 14.63341892],
#        [ 16.64595501],
#        [  3.56447042],
#        [ 60.92174898],
#        [ 85.07218205],
#        [ 74.00323356],
#        [ 58.90921289],
#        [  7.5895426 ],
#        [ 20.67102718],
#        [ 57.90294484],
#        [ 98.15366663],
#        [ 26.70863545],
#        [ -0.46060176],
#        [ 94.12859445],
#        [ 66.95935724],
#        [ 49.85280048],
#        [ 51.86533657],
# ...

# %%
y_test
# Out:
# array([[ 87.67388681],
#        [ -0.1218605 ],
#        [ 43.64765048],
#        [ 41.39990349],
#        [ 48.71787679],
#        [ 55.9249564 ],
#        [ 47.04654956],
#        [ 86.236707  ],
#        [ 13.11612884],
#        [ 61.94273962],
#        [ 94.55203143],
#        [ 74.12151511],
#        [ 22.5453232 ],
#        [ 16.01629889],
#        [ 76.92664854],
#        [100.0953697 ],
#        [ 84.48045678],
#        [ 83.1286166 ],
#        [ 17.9170699 ],
#        [ 69.02934339],
#        [  2.26705945],
#        [ 56.37058203],
#        [ 61.7510743 ],
#        [ 17.21865634],
#        [ 17.33681562],
#        [  9.68240849],
#        [ 66.16652565],
#        [ 82.69087513],
#        [ 72.6356699 ],
#        [ 61.69026202],
#        [ 10.240085  ],
#        [ 22.51016575],
#        [ 54.14681616],
#        [ 92.85929155],
#        [ 26.68273277],
#        [ -3.83665214],
#        [ 96.19000542],
#        [ 65.84975426],
#        [ 49.82634062],
#        [ 51.70352433],
# ...

# %%
clf.score(x_test,y_test)
# Out:
# 0.9906820924930846
